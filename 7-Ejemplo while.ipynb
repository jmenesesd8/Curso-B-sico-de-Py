# %%
def run():
    # for contador in range(1000):
    #     if contador % 2 != 0:
    #         continue # salta lo que sigue después de esta instrucción
    #     print(contador)
   



    #for i in range(1,101):
         #print(i)
         #if i ==78:
            #break
         



    texto = input('Escribe un texto: ')
    for letra in texto:
     if letra == 'o':
      break
     print(letra)
    
    #Tarea:Usar while con continue
    #numero=0
    #while numero < 50:
        #numero = numero + 1
        #print(numero)
        #if numero % 2 != 0 :
           #continue
        #else:
         #print(numero)



         
if __name__ == '__main__':
    run()
# Out:
# Escribe un texto: control
# c

# %%
s='hola'
a=s/2
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-a7a4962a587e> in <module>()
#       1 s='hola'
# ----> 2 a=s/2
#       3 print(a)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
