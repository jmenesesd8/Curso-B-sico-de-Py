# %%
nombre="ZORRA"
#nombre=nombre[0:3]#muestra desde la primera posición hasta 1 antes del valor dado(osea 2 para el caso)
#print(nombre)
#nombre=nombre[2:3]#si no se coloca el primer número del intervalo, se toma como cero
#print(nombre)
#nombre=nombre[3:]#si no se coloca el ultimo número del intervalo, se toma hasta el final
#print(nombre)
#nombre=nombre[1:5]#recorre de la posición 1 hasta la prosición 5-1
#print(nombre)
#nombre=nombre[1:5:2]#recorre de la posición 1 hasta la prosición 5-1 de dos en dos
#print(nombre)
#nombre=nombre[::]#recorre del inicio al final la cadena de texto
#print(nombre)
nombre=nombre[::-1]#recorre del final al inicio
print(nombre)
#nombre=nombre[1:2]#recorre del final al inicio
#print(nombre)
# Out:
# ARROZ
