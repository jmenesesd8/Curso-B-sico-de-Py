# %%
def palindromo(palabra):
    palabra = palabra.replace(' ', '')# quitar los espacios
    palabra = palabra.lower()#colocar todo en minúscula
    palabra_invertida = palabra[::-1]#comparar con la lectura al revés de la palabra y si coincide es palindromo
    print(palabra_invertida)
    if palabra == palabra_invertida:
        return True
    else:
        return False


def run():
    palabra = input('Escribe una palabra: ')
    es_palindromo = palindromo(palabra)
    if es_palindromo == True:
        print('Es palíndromo')
    else:
        print('No es palíndromo')


if __name__ == '__main__':#Buena practica para llamar una función en Python
    run()
# Out:
# Escribe una palabra: somos
# somos
# Es palíndromo

# %%
s='hola'
a=s*5
print(a)
# Out:
# holaholaholaholahola

# %%
Palabra=input("Ingrese una palabra por favor:")

  if str(Palabra[::])==Palabra str()
    print("es un polindromo")
  else:
    print("NO es un polindromo")
