# %%
numeros=[1,2,3,4]
print(numeros)
# Out:
# [1, 2, 3, 4]

# %%
lista=['hola',1,True]
print(lista)
# Out:
# ['hola', 1, True]

# %%
lista.append(5)#Método para agregar un caracter al final de la lista

# %%
print(lista)
# Out:
# ['hola', 1, True, 5]

# %%
lista.pop(0)#Eliminar un caracter de las lista
# Out:
# 'hola'

# %%
print(lista)
# Out:
# [1, True, 5]

# %%
for i in lista:#recorrer una lista
  print(i)
# Out:
# 1
# True
# 5

# %%
numeros=[1,2,3]
numeros1=[4,5,6]
suma=numeros+numeros1#se puede concatenar las listas
print(suma)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
multip=numeros*5#Se repite 5 veces la lista
print(multip)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]
